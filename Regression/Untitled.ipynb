# %%
print("hello world")
# Out:
# hello world

# %%
print("Arnav Dada Is BOAT")
# Out:
# Arnav Dada Is BOAT

# %%
x = 50
y  = 40
z = x+y
print("z")
# Out:
# z

# %%
a = 2 
b = 5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 7
# -3
# 10
# 0.4

# %%
print( a  **   b)
# Out:
# 32
